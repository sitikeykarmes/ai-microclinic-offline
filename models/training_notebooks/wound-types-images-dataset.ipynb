# %%
import os
import numpy as np
import cv2
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

# %%
# Define dataset path
dataset_path = "../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy"

# %%
# Preprocess image
def preprocess_image(img):
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    img = cv2.resize(img, (299, 299))  # Resize to 299x299
    img = img.astype('float32')
    img = preprocess_input(img)  # Preprocess for ResNet50
    return img

# %%
# Load and preprocess data
def load_data(data_path):
    data = []
    labels = []
    for folder in os.listdir(data_path):
        folder_path = os.path.join(data_path, folder)
        if os.path.isdir(folder_path):  # Ensure it's a directory
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                img = cv2.imread(file_path)
                if img is not None:  # Check if the image was loaded successfully
                    img = preprocess_image(img)  # Apply preprocessing to each image
                    data.append(img)
                    labels.append(folder)
    return np.array(data), np.array(labels)

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input  # Import preprocess_input
# Load all data
X, y = load_data(dataset_path)

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
y_categorical = to_categorical(y_encoded, num_classes=len(label_encoder.classes_))

# Split data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
# Print shapes
print("Training data shape:", X_train.shape)
print("Validation data shape:", X_val.shape)
print("Training labels shape:", y_train.shape)
print("Validation labels shape:", y_val.shape)
# Out:
# Training data shape: (2298, 299, 299, 3)
# Validation data shape: (575, 299, 299, 3)
# Training labels shape: (2298, 12)
# Validation labels shape: (575, 12)

# %%
# Data Augmentation to reduce overfitting
datagen = ImageDataGenerator(
    rotation_range=30,  # Randomly rotate images by 30 degrees
    width_shift_range=0.2,  # Randomly shift images horizontally by 20%
    height_shift_range=0.2,  # Randomly shift images vertically by 20%
    shear_range=0.2,  # Apply shear transformations
    zoom_range=0.3,  # Randomly zoom in/out by 30%
    brightness_range=[0.7, 1.3],  # Randomly adjust brightness
    horizontal_flip=True,  # Randomly flip images horizontally
    fill_mode='nearest'  # Fill missing pixels with the nearest value
)
datagen.fit(X_train)

# %%
# Build the model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
for layer in base_model.layers[:-10]:  # Fine-tune more layers
    layer.trainable = False

model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    BatchNormalization(),
    Dense(512, activation='relu', kernel_regularizer='l2'),  # Add L2 regularization
    Dropout(0.5),  # Add Dropout to reduce overfitting
    Dense(len(label_encoder.classes_), activation='softmax')  # Match number of classes
])

# Convert one-hot encoded labels back to integer labels
y_train_int = np.argmax(y_train, axis=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 25s 0us/step

# %%
# Compute class weights to handle class imbalance
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_int),  # Unique classes in the training set
    y=y_train_int  # Integer training labels
)
class_weights_dict = dict(enumerate(class_weights))  # Convert to dictionary

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Callbacks
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6)  # Reduce learning rate on plateau
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)  # Early stopping to prevent overfitting

# Train the model with data augmentation
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),  # Use augmented data
    validation_data=(X_val, y_val),
    epochs=50,
    class_weight=class_weights_dict,
    callbacks=[lr_scheduler, early_stopping]
)
# Out:
# c:\Users\karti\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.1797 - loss: 11.1836 - val_accuracy: 0.6122 - val_loss: 9.2231 - learning_rate: 1.0000e-04
# Epoch 2/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.5114 - loss: 9.3071 - val_accuracy: 0.7357 - val_loss: 8.6396 - learning_rate: 1.0000e-04
# Epoch 3/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.6588 - loss: 8.6650 - val_accuracy: 0.7948 - val_loss: 8.2907 - learning_rate: 1.0000e-04
# Epoch 4/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - accuracy: 0.7121 - loss: 8.2337 - val_accuracy: 0.8139 - val_loss: 8.0148 - learning_rate: 1.0000e-04
# Epoch 5/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.7373 - loss: 7.9495 - val_accuracy: 0.8278 - val_loss: 7.7032 - learning_rate: 1.0000e-04
# Epoch 6/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.7898 - loss: 7.5926 - val_accuracy: 0.8330 - val_loss: 7.4711 - learning_rate: 1.0000e-04
# Epoch 7/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.8062 - loss: 7.3170 - val_accuracy: 0.8609 - val_loss: 7.1890 - learning_rate: 1.0000e-04
# Epoch 8/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.7991 - loss: 7.0790 - val_accuracy: 0.8678 - val_loss: 6.9064 - learning_rate: 1.0000e-04
# Epoch 9/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.8538 - loss: 6.7109 - val_accuracy: 0.8852 - val_loss: 6.6146 - learning_rate: 1.0000e-04
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.8715 - loss: 6.4434 - val_accuracy: 0.8887 - val_loss: 6.3550 - learning_rate: 1.0000e-04
# Epoch 11/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.8884 - loss: 6.1752 - val_accuracy: 0.8939 - val_loss: 6.0950 - learning_rate: 1.0000e-04
# Epoch 12/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 119s 2s/step - accuracy: 0.9015 - loss: 5.9130 - val_accuracy: 0.9061 - val_loss: 5.8481 - learning_rate: 1.0000e-04
# Epoch 13/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9069 - loss: 5.6486 - val_accuracy: 0.9165 - val_loss: 5.5904 - learning_rate: 1.0000e-04
# Epoch 14/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9132 - loss: 5.4204 - val_accuracy: 0.9078 - val_loss: 5.3488 - learning_rate: 1.0000e-04
# Epoch 15/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9028 - loss: 5.1686 - val_accuracy: 0.9270 - val_loss: 5.0690 - learning_rate: 1.0000e-04
# Epoch 16/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9414 - loss: 4.8877 - val_accuracy: 0.9235 - val_loss: 4.8221 - learning_rate: 1.0000e-04
# Epoch 17/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.9141 - loss: 4.6687 - val_accuracy: 0.9270 - val_loss: 4.5848 - learning_rate: 1.0000e-04
# Epoch 18/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.9342 - loss: 4.4226 - val_accuracy: 0.9252 - val_loss: 4.3594 - learning_rate: 1.0000e-04
# Epoch 19/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.9388 - loss: 4.1910 - val_accuracy: 0.9374 - val_loss: 4.1416 - learning_rate: 1.0000e-04
# Epoch 20/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.9433 - loss: 3.9575 - val_accuracy: 0.9252 - val_loss: 3.9390 - learning_rate: 1.0000e-04
# Epoch 21/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9517 - loss: 3.7539 - val_accuracy: 0.9391 - val_loss: 3.6800 - learning_rate: 1.0000e-04
# Epoch 22/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9543 - loss: 3.5195 - val_accuracy: 0.9565 - val_loss: 3.4755 - learning_rate: 1.0000e-04
# Epoch 23/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 120s 2s/step - accuracy: 0.9666 - loss: 3.3078 - val_accuracy: 0.9496 - val_loss: 3.3296 - learning_rate: 1.0000e-04
# Epoch 24/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9634 - loss: 3.1224 - val_accuracy: 0.9583 - val_loss: 3.0883 - learning_rate: 1.0000e-04
# Epoch 25/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9591 - loss: 2.9471 - val_accuracy: 0.9548 - val_loss: 2.9209 - learning_rate: 1.0000e-04
# Epoch 26/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9619 - loss: 2.7489 - val_accuracy: 0.9565 - val_loss: 2.7458 - learning_rate: 1.0000e-04
# Epoch 27/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9733 - loss: 2.5613 - val_accuracy: 0.9374 - val_loss: 2.6193 - learning_rate: 1.0000e-04
# Epoch 28/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.9660 - loss: 2.3997 - val_accuracy: 0.9565 - val_loss: 2.3973 - learning_rate: 1.0000e-04
# Epoch 29/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9757 - loss: 2.2325 - val_accuracy: 0.9583 - val_loss: 2.2483 - learning_rate: 1.0000e-04
# Epoch 30/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9822 - loss: 2.0725 - val_accuracy: 0.9496 - val_loss: 2.1075 - learning_rate: 1.0000e-04
# Epoch 31/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - accuracy: 0.9749 - loss: 1.9337 - val_accuracy: 0.9617 - val_loss: 1.9407 - learning_rate: 1.0000e-04
# Epoch 32/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.9806 - loss: 1.7816 - val_accuracy: 0.9670 - val_loss: 1.8171 - learning_rate: 1.0000e-04
# Epoch 33/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.9777 - loss: 1.6620 - val_accuracy: 0.9513 - val_loss: 1.7057 - learning_rate: 1.0000e-04
# Epoch 34/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 159s 2s/step - accuracy: 0.9739 - loss: 1.5415 - val_accuracy: 0.9548 - val_loss: 1.5867 - learning_rate: 1.0000e-04
# Epoch 35/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9839 - loss: 1.4185 - val_accuracy: 0.9548 - val_loss: 1.4788 - learning_rate: 1.0000e-04
# Epoch 36/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.9842 - loss: 1.3037 - val_accuracy: 0.9548 - val_loss: 1.3676 - learning_rate: 1.0000e-04
# Epoch 37/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - accuracy: 0.9830 - loss: 1.1962 - val_accuracy: 0.9565 - val_loss: 1.2822 - learning_rate: 1.0000e-04
# Epoch 38/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.9857 - loss: 1.1063 - val_accuracy: 0.9635 - val_loss: 1.1686 - learning_rate: 1.0000e-04
# Epoch 39/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.9844 - loss: 1.0130 - val_accuracy: 0.9583 - val_loss: 1.0880 - learning_rate: 1.0000e-04
# Epoch 40/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.9819 - loss: 0.9506 - val_accuracy: 0.9635 - val_loss: 1.0043 - learning_rate: 1.0000e-04
# Epoch 41/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.9839 - loss: 0.8613 - val_accuracy: 0.9600 - val_loss: 0.9400 - learning_rate: 1.0000e-04
# Epoch 42/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9837 - loss: 0.7865 - val_accuracy: 0.9496 - val_loss: 0.9397 - learning_rate: 1.0000e-04
# Epoch 43/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 122s 2s/step - accuracy: 0.9855 - loss: 0.7214 - val_accuracy: 0.9530 - val_loss: 0.8372 - learning_rate: 1.0000e-04
# Epoch 44/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.9924 - loss: 0.6492 - val_accuracy: 0.9635 - val_loss: 0.7408 - learning_rate: 1.0000e-04
# Epoch 45/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.9879 - loss: 0.5925 - val_accuracy: 0.9583 - val_loss: 0.7188 - learning_rate: 1.0000e-04
# Epoch 46/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.9771 - loss: 0.6574 - val_accuracy: 0.9409 - val_loss: 0.7099 - learning_rate: 1.0000e-04
# Epoch 47/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.9822 - loss: 0.5309 - val_accuracy: 0.9600 - val_loss: 0.6704 - learning_rate: 1.0000e-04
# Epoch 48/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.9897 - loss: 0.4686 - val_accuracy: 0.9513 - val_loss: 0.6130 - learning_rate: 1.0000e-04
# Epoch 49/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - accuracy: 0.9897 - loss: 0.4311 - val_accuracy: 0.9548 - val_loss: 0.5679 - learning_rate: 1.0000e-04
# Epoch 50/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 128s 2s/step - accuracy: 0.9863 - loss: 0.4097 - val_accuracy: 0.9513 - val_loss: 0.5631 - learning_rate: 1.0000e-04

# %%
# Plot training and validation loss and accuracy
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='Training Loss', marker='o', color='blue')
plt.plot(epochs, val_loss, label='Validation Loss', marker='o', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, label='Training Accuracy', marker='o', color='blue')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', marker='o', color='red')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Predict on the validation set
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_val, axis=1)

# Print classification report
print(classification_report(y_true_classes, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step
#                  precision    recall  f1-score   support
#
#       Abrasions       0.67      0.77      0.71        13
#         Bruises       0.96      0.98      0.97        44
#           Burns       0.93      0.93      0.93        28
#             Cut       0.96      0.93      0.95        29
# Diabetic Wounds       0.91      1.00      0.95        83
#   Ingrown_nails       1.00      1.00      1.00         5
#      Laseration       0.96      1.00      0.98        24
#          Normal       1.00      1.00      1.00        38
# Pressure Wounds       0.98      0.89      0.93       122
#      Stab_wound       0.33      0.50      0.40         2
# Surgical Wounds       0.99      0.97      0.98        88
#   Venous Wounds       0.96      0.98      0.97        99
#
#        accuracy                           0.95       575
#       macro avg       0.89      0.91      0.90       575
#    weighted avg       0.95      0.95      0.95       575

# %%
# Plot confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=label_encoder.classes_, 
            yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Save the model
model.save('../../../ai-microclinic-offline-dataset/Wound Dataset/wound_classification_model.h5')
print("Model saved as 'wound_classification_model.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as 'wound_classification_model.h5'

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Abrasions/abrasions (10).jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# True Label: Abrasions
# Predicted Label: Abrasions

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Burns/burns (10).jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# True Label: Burns
# Predicted Label: Burns

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Burns/burns (23).jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# True Label: Burns
# Predicted Label: Burns

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Bruises/bruises (99).jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# True Label: Bruises
# Predicted Label: Bruises

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Cut/cut (16).jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# True Label: Cut
# Predicted Label: Cut

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Laseration/laseration (16).jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# True Label: Laseration
# Predicted Label: Laseration

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Laseration/laseration (24).jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# True Label: Laseration
# Predicted Label: Laseration

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Pressure Wounds/13_0.jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# True Label: Pressure Wounds
# Predicted Label: Pressure Wounds

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.preprocessing import LabelEncoder

# Define and fit LabelEncoder on the labels
le = LabelEncoder()
le.fit(y)  # y is the original labels of the dataset

# Function to preprocess the image
def preprocess_image(img):
    # Convert BGR to RGB for consistency
    if img.shape[2] == 3:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # Resize the image to match the model's input size (299, 299 for ResNet50)
    img = cv2.resize(img, (299, 299))
    img = img.astype('float32')
    img = preprocess_input(img)  # Use preprocess_input based on the model
    return img

# Function to predict the class of an image
def predict_image_class(model, image_path, label_encoder):
    # Load the image
    img = cv2.imread(image_path)
    
    # Extract the true label from the image path
    true_label = image_path.split('/')[-2]  # Assumes the folder name is the true label
    
    # Check if the image was successfully loaded
    if img is None:
        print(f"Error: Unable to load the image at {image_path}")
        return
    
    # Display the uploaded image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct color display
    plt.axis('off')  # Hide axis
    plt.title(f"Uploaded Image (True Label: {true_label})")
    plt.show()

    # Preprocess the image and make a prediction
    img = preprocess_image(img)  # Apply preprocessing function
    img = np.expand_dims(img, axis=0)  # Add batch dimension for prediction

    # Make a prediction
    predictions = model.predict(img)
    predicted_class_index = np.argmax(predictions)
    predicted_label = label_encoder.classes_[predicted_class_index]

    # Print the true label and predicted label
    print(f'True Label: {true_label}')
    print(f'Predicted Label: {predicted_label}')

# Example usage
image_path = '../../../ai-microclinic-offline-dataset/Wound Dataset/Wound_dataset copy/Normal/2.jpg'  
predict_image_class(model, image_path, label_encoder)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# True Label: Normal
# Predicted Label: Normal
